# %% [markdown]
# # NLPipe - Demo (simple)
# <p>#TODO: Needs description of what this file is</p>

# %% [markdown]
# # Initialize environment

# %%
import sys
import os

PROJECT_DIR = f'{os.getcwd()}'
DEMO_DATA_DIR = f'{os.getcwd()}/data'
DEMO_DATA_FILE = f'{DEMO_DATA_DIR}/IMDB Dataset.csv.gz'
UTILITIES_DIR = f'{PROJECT_DIR}/utilities'

# Add the UTILITY_DIR to the path to import files
sys.path.append(UTILITIES_DIR)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load Data
# <p>Loading the IMDB Dataset<br>
# 50,000 records on pos/neg sentiment analysis<br>
# 25,000 records per class<br>

# %%
# Loading the IMDB Dataset
ORIG_DF = pd.read_csv(DEMO_DATA_FILE, compression='gzip')

# Changing target column from string to 0,1. Label encoding not yet included in framework
ORIG_DF['sentiment'] = np.where(ORIG_DF['sentiment']=='positive', 1, 0)

print(f'Data shape: {ORIG_DF.shape}')
display(ORIG_DF.head())
# Out:
# Data shape: (50000, 2)
#                                               review  sentiment
# 0  One of the other reviewers has mentioned that ...          1
# 1  A wonderful little production. <br /><br />The...          1
# 2  I thought this was a wonderful way to spend ti...          1
# 3  Basically there's a family where a little boy ...          0
# 4  Petter Mattei's "Love in the Time of Money" is...          1

# %%
# Setting up variables for later usage in DataPackage
DATA_COLUMN = 'review'
TARGET_COLUMN = 'sentiment'
UNIQUE_COLUMN = None   # Unique index column. If None, one will be created

# %% [markdown]
# # DataPackageParams
# <p>#TODO: Needs description of what DataPackageParams is</p>

# %%
# DataPackageParams are optional. Can do it manually or store and save the params for re-run
from DataPackage import DataPackageParams
myDPP = DataPackageParams(
                    process_params=False, # True=run all data cleanup/setup on load
                    
                    # Class Balance
                    sample_size = None, # Can be set to an absolute value. None means undersample to smallest
                                        
                    # Text Cleaning Params
                    fix_unicode=True,  # fix various unicode errors
                    to_ascii=True,  # transliterate to closest ASCII representation
                    lower=True,  # lowercase text
                    no_line_breaks=False,  # fully strip line breaks as opposed to only normalizing them
                    no_urls=False,  # replace all URLs with a special token
                    no_emails=False,  # replace all email addresses with a special token
                    no_phone_numbers=False,  # replace all phone numbers with a special token
                    no_numbers=True,  # replace all numbers with a special token
                    no_digits=False,  # replace all digits with a special token
                    no_currency_symbols=False,  # replace all currency symbols with a special token
                    no_punct=False,  # remove punctuations
                    replace_with_punct="",  # instead of removing punctuations you may replace them
                    replace_with_url="<URL>",
                    replace_with_email="<EMAIL>",
                    replace_with_phone_number="<PHONE>",
                    replace_with_number="",
                    replace_with_digit="0",
                    replace_with_currency_symbol="<CUR>",
                    lang="en",  # set to 'de' for German special handling

                    # Remove stopwords
                    remove_stopwords=True, # Removes stopwords
                    stopword_language='english',
        
                    # train test split params
                    stratifyColumn=None, # If None will be autoset to target_column in DataPackage
                    train_size=0.8, # Can be percent or absolute number
                    random_state=765,
                    shuffle=True,

                    # Encoding params
                    encoding_type='TFIDF', # Currently only supports TFIDF encoding, TBA: BERT, GLOVE, Word2Vec
                    max_features=100 # Currently only used in TFIDF
                    )

# %% [markdown]
# # Data Package
# <p>#TODO: Needs description of what this file is</p>

# %%
# Create the DataPackage
from DataPackage import DataPackage
myDP = DataPackage(original_data = ORIG_DF,
                   data_column = DATA_COLUMN,
                   target_column = TARGET_COLUMN,
                   unique_column = UNIQUE_COLUMN,
                   data_package_params = myDPP)

# %% [markdown]
# # Experiment Manager

# %%
from ExperimentManager import ExperimentManager

# %%
# Create the classifier used for the first Experiment
from xgboost import XGBClassifier
classifier1 = XGBClassifier(eval_metric='mlogloss', 
                            tree_method='gpu_hist',
                            gpu_id = 0,
                            predictor='gpu_predictor',
                            use_label_encoder=False,
                            max_depth=10,
                            n_estimators=100)

# %%
# Create the Experiment Manager 
myEM = ExperimentManager(project_name='NLPipe',
                         experiment_name='XGB depth:10 est:100',
                         classifier=classifier1,
                         data_package=myDP)
# Out:
# DataPackage summary
# Attributes:
# ---> uniqueColumn: uuid
# ---> dataColumn: review
# ---> targetColumn: sentiment
# Original Data:
# ---> original data shape: (50000, 3)
# Working Data:
# ---> working data shape: (50000, 3)
# Process:
# ---> isProcessed: False
# ---> isCleaned: False
# ---> isStopWorded: False
# ---> isBalanced: False
# ---> isEncoded: False
# ---> isTrainTestSplit: False
# Data:
# ---> isOrigDataLoaded: True
# ---> isTrainDataLoaded: False
# ---> isTestDataLoaded: False
#
# DataExperiment summary:
# ---> projectName: NLPipe
# ---> experimentName: XGB depth:10 est:100
# ---> isDataPackageLoaded: True
# ---> isProcessed: False
# ---> isModelLoaded: False
# ---> isModelPredicted: False
# ---> isModelLearningCurveCreated: False
# ---> isClassifierLoaded: True
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eval_metric='mlogloss', gamma=None,
#               gpu_id=0, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=10,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor='gpu_predictor', random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=None,
#               tree_method='gpu_hist', use_label_encoder=False,
#               validate_parameters=None, verbosity=None)

# %%
# Add another experiment
from sklearn.ensemble import RandomForestClassifier

classifier2 = XGBClassifier(eval_metric='mlogloss', 
                           tree_method='gpu_hist',
                           use_label_encoder=False,
                           max_depth=10,
                           n_estimators=50)

myEM.add_experiment(experiment_name='XGB depth:10 est:50',
                    classifier=classifier2)
# Out:
# DataExperiment summary:
# ---> projectName: NLPipe
# ---> experimentName: XGB depth:10 est:50
# ---> isDataPackageLoaded: True
# ---> isProcessed: False
# ---> isModelLoaded: False
# ---> isModelPredicted: False
# ---> isModelLearningCurveCreated: False
# ---> isClassifierLoaded: True
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eval_metric='mlogloss', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=10,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=None,
#               tree_method='gpu_hist', use_label_encoder=False,
#               validate_parameters=None, verbosity=None)

# %%
# Add another experiment
classifier3 = XGBClassifier(eval_metric='mlogloss', 
                           tree_method='gpu_hist',
                           use_label_encoder=False,
                           max_depth=3,
                           n_estimators=100)

myEM.add_experiment(experiment_name='XGB depth:3 est:100',
                    classifier=classifier3)
# Out:
# DataExperiment summary:
# ---> projectName: NLPipe
# ---> experimentName: XGB depth:3 est:100
# ---> isDataPackageLoaded: True
# ---> isProcessed: False
# ---> isModelLoaded: False
# ---> isModelPredicted: False
# ---> isModelLearningCurveCreated: False
# ---> isClassifierLoaded: True
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eval_metric='mlogloss', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=3,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=None,
#               tree_method='gpu_hist', use_label_encoder=False,
#               validate_parameters=None, verbosity=None)

# %%
# Add another experiment
classifier4 = XGBClassifier(eval_metric='mlogloss', 
                           tree_method='gpu_hist',
                           use_label_encoder=False,
                           max_depth=3,
                           n_estimators=50)

myEM.add_experiment(experiment_name='XGB depth:3 est:50',
                    classifier=classifier4)
# Out:
# DataExperiment summary:
# ---> projectName: NLPipe
# ---> experimentName: XGB depth:3 est:50
# ---> isDataPackageLoaded: True
# ---> isProcessed: False
# ---> isModelLoaded: False
# ---> isModelPredicted: False
# ---> isModelLearningCurveCreated: False
# ---> isClassifierLoaded: True
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eval_metric='mlogloss', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=3,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=None,
#               tree_method='gpu_hist', use_label_encoder=False,
#               validate_parameters=None, verbosity=None)

# %%
# Add another experiment
classifier5 = XGBClassifier(eval_metric='mlogloss', 
                           tree_method='gpu_hist',
                           use_label_encoder=False,
                           max_depth=3,
                           n_estimators=20)

myEM.add_experiment(experiment_name='XGB depth:3 est:20',
                    classifier=classifier5)
# Out:
# DataExperiment summary:
# ---> projectName: NLPipe
# ---> experimentName: XGB depth:3 est:20
# ---> isDataPackageLoaded: True
# ---> isProcessed: False
# ---> isModelLoaded: False
# ---> isModelPredicted: False
# ---> isModelLearningCurveCreated: False
# ---> isClassifierLoaded: True
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eval_metric='mlogloss', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=3,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=20, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=None,
#               tree_method='gpu_hist', use_label_encoder=False,
#               validate_parameters=None, verbosity=None)

# %% [markdown]
# # ExperimentManager - run_experiment

# %%
myEM.list_experiments()
# Out:
# idx Processed Experiment name
#   0     False XGB depth:10 est:100
#   1     False XGB depth:10 est:50
#   2     False XGB depth:3 est:100
#   3     False XGB depth:3 est:50
#   4     False XGB depth:3 est:20

# %%
axis_labels = [0,1] #This won't be needed once the label encoder has been included
myEM.run_experiment(axis_labels=axis_labels,
                    n_jobs=-1,  # -1 means use all available processors, otherwise include number
                    index=None) # index=None means process all experiements, 
                                # otherwise provide index of single experiment to run
# Out:
# Data package has not been processed. Processing now.
# -------------------------------------------------------
# DataPackage summary
# Attributes:
# ---> uniqueColumn: uuid
# ---> dataColumn: review
# ---> targetColumn: sentiment
# Original Data:
# ---> original data shape: (50000, 3)
# Working Data:
# ---> working data shape: (50000, 3)
# Process:
# ---> isProcessed: False
# ---> isCleaned: False
# ---> isStopWorded: False
# ---> isBalanced: False
# ---> isEncoded: False
# ---> isTrainTestSplit: False
# Data:
# ---> isOrigDataLoaded: True
# ---> isTrainDataLoaded: False
# ---> isTestDataLoaded: False
#
# Processing data package with provided parameters
# Undersampling data to match min class: 0 of size: 25000
#    sentiment  ttlCol
# 0          0   25000
# 1          1   25000
# Cleaning text column...
# 100%|███████████████████████████████████| 50000/50000 [00:20<00:00, 2385.63it/s]
# [nltk_data] Downloading package stopwords to /home/magni/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Removing stopwords...
# 100%|███████████████████████████████████| 50000/50000 [00:09<00:00, 5350.05it/s]
# Encoding to TF-IDF with max_features=100
# Encoding completed. Feature list:
# ['acting', 'actors', 'actually', 'all', 'also', 'and', 'another', 'around', 'back', 'bad', 'best', 'better', 'big', 'br', 'can', 'cast', 'character', 'characters', 'could', 'director', 'end', 'even', 'ever', 'every', 'film', 'films', 'find', 'first', 'funny', 'get', 'go', 'going', 'good', 'got', 'great', 'he', 'horror', 'however', 'in', 'it', 'know', 'life', 'like', 'little', 'look', 'lot', 'love', 'made', 'make', 'makes', 'man', 'many', 'movie', 'movies', 'much', 'never', 'new', 'nothing', 'old', 'one', 'part', 'people', 'plot', 'pretty', 'quite', 'real', 'really', 'say', 'scene', 'scenes', 'see', 'seems', 'seen', 'show', 'something', 'still', 'story', 'take', 'that', 'the', 'there', 'thing', 'things', 'think', 'this', 'though', 'time', 'two', 'us', 've', 'want', 'watch', 'watching', 'way', 'well', 'work', 'world', 'would', 'years', 'young']
#
# Completed train/test split (train_size = 0.8):
# ---> Original data size: 50000
# ---> Training data size: 40000
# ---> Testing data size: 10000
# ---> Stratified on column: sentiment
#
# Processing data package has been completed
#
# DataPackage summary
# Attributes:
# ---> uniqueColumn: uuid
# ---> dataColumn: review
# ---> targetColumn: sentiment
# Original Data:
# ---> original data shape: (50000, 3)
# Working Data:
# ---> working data shape: (50000, 102)
# Process:
# ---> isProcessed: True
# ---> isCleaned: True
# ---> isStopWorded: True
# ---> isBalanced: True
# ---> isEncoded: True
# ---> isTrainTestSplit: True
# Data:
# ---> isOrigDataLoaded: True
# ---> isTrainDataLoaded: True
# ---> isTestDataLoaded: True
#
# =======================================================
#
#
# -------------------------------------------------------
# Processing experiment: [0] XGB depth:10 est:100
# Training model for XGB depth:10 est:100
# Predicting model for XGB depth:10 est:100
# Model Stats:
#              Experiment  Accuracy  Precision  Recall  F1 Score  Cohen kappa
# 0  XGB depth:10 est:100      0.71       0.71    0.71      0.71         0.42
#
# [learning_curve] Training set sizes: [ 3200  6400 16000 32000]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  20 | elapsed:   31.4s remaining:  3.0min
# [Parallel(n_jobs=-1)]: Done   9 out of  20 | elapsed:   49.0s remaining:   59.9s
# [Parallel(n_jobs=-1)]: Done  15 out of  20 | elapsed:  1.0min remaining:   20.3s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:  1.1min finished
# =======================================================
#
#
# -------------------------------------------------------
# Processing experiment: [1] XGB depth:10 est:50
# Training model for XGB depth:10 est:50
# Predicting model for XGB depth:10 est:50
# Model Stats:
#             Experiment  Accuracy  Precision  Recall  F1 Score  Cohen kappa
# 0  XGB depth:10 est:50      0.72       0.72    0.72      0.72         0.43
#
# [learning_curve] Training set sizes: [ 3200  6400 16000 32000]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  20 | elapsed:   18.3s remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done   9 out of  20 | elapsed:   32.3s remaining:   39.4s
# [Parallel(n_jobs=-1)]: Done  15 out of  20 | elapsed:   35.9s remaining:   12.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   37.7s finished
# =======================================================
#
#
# -------------------------------------------------------
# Processing experiment: [2] XGB depth:3 est:100
# Training model for XGB depth:3 est:100
# Predicting model for XGB depth:3 est:100
# Model Stats:
#             Experiment  Accuracy  Precision  Recall  F1 Score  Cohen kappa
# 0  XGB depth:3 est:100      0.73       0.73    0.73      0.73         0.45
#
# [learning_curve] Training set sizes: [ 3200  6400 16000 32000]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  20 | elapsed:    3.1s remaining:   17.3s
# [Parallel(n_jobs=-1)]: Done   9 out of  20 | elapsed:    4.1s remaining:    5.0s
# [Parallel(n_jobs=-1)]: Done  15 out of  20 | elapsed:    4.2s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    4.4s finished
# =======================================================
#
#
# -------------------------------------------------------
# Processing experiment: [3] XGB depth:3 est:50
# Training model for XGB depth:3 est:50
# Predicting model for XGB depth:3 est:50
# Model Stats:
#            Experiment  Accuracy  Precision  Recall  F1 Score  Cohen kappa
# 0  XGB depth:3 est:50      0.72       0.72    0.72      0.72         0.44
#
# [learning_curve] Training set sizes: [ 3200  6400 16000 32000]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  20 | elapsed:    1.3s remaining:    7.6s
# [Parallel(n_jobs=-1)]: Done   9 out of  20 | elapsed:    2.2s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done  15 out of  20 | elapsed:    2.6s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    2.7s finished
# =======================================================
#
#
# -------------------------------------------------------
# Processing experiment: [4] XGB depth:3 est:20
# Training model for XGB depth:3 est:20
# Predicting model for XGB depth:3 est:20
# Model Stats:
#            Experiment  Accuracy  Precision  Recall  F1 Score  Cohen kappa
# 0  XGB depth:3 est:20       0.7       0.71     0.7       0.7         0.41
#
# [learning_curve] Training set sizes: [ 3200  6400 16000 32000]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  20 | elapsed:    0.7s remaining:    4.2s
# [Parallel(n_jobs=-1)]: Done   9 out of  20 | elapsed:    1.2s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done  15 out of  20 | elapsed:    1.6s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    1.8s finished
# =======================================================
#
#
# Processing experiments complete.
#              Experiment  Accuracy  Precision  Recall  F1 Score  Cohen kappa
# 0  XGB depth:10 est:100      0.71       0.71    0.71      0.71         0.42
# 1   XGB depth:10 est:50      0.72       0.72    0.72      0.72         0.43
# 2   XGB depth:3 est:100      0.73       0.73    0.73      0.73         0.45
# 3    XGB depth:3 est:50      0.72       0.72    0.72      0.72         0.44
# 4    XGB depth:3 est:20      0.70       0.71    0.70      0.70         0.41

# %% [markdown]
# # Experiment Summary

# %%
myEM.display_experiment_summary(index=0, axisLabels=axis_labels)
# Out:
# Displaying summary for experiment: XGB depth:10 est:100
# Model Stats:
#              Experiment  Accuracy  Precision  Recall  F1 Score  Cohen kappa
# 0  XGB depth:10 est:100      0.71       0.71    0.71      0.71         0.42
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.70      0.71      5000
#            1       0.71      0.72      0.72      5000
#
#     accuracy                           0.71     10000
#    macro avg       0.71      0.71      0.71     10000
# weighted avg       0.71      0.71      0.71     10000
# Model ROCAUC not calculated. Starting now
#   0%|          | 0/101 [00:00<?, ?it/s]
# <lime.lime_tabular.LimeTabularExplainer object at 0x7f0554def110>
# predicted [1]
# actual 0
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s

# %%
#myEM.display_experiment_summary(index=1, axisLabels=axis_labels)

# %% [markdown]
# # SHAP

# %%
myEM.show_shap_waterfall(model_index=0,
                         value_index=0)
# Out:
# SHAP values not calculated. Generating now
# Calculating shap_values for XGB depth:10 est:100
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
myEM.show_shap_waterfall(model_index=1,
                         value_index=0)
# Out:
# SHAP values not calculated. Generating now
# Calculating shap_values for XGB depth:10 est:50

# %%
myEM.show_shap_waterfall(model_index=2,
                         value_index=0)
# Out:
# SHAP values not calculated. Generating now
# Calculating shap_values for XGB depth:3 est:100

# %%
myEM.show_shap_waterfall(model_index=3,
                         value_index=0)
# Out:
# SHAP values not calculated. Generating now
# Calculating shap_values for XGB depth:3 est:50

# %%
myEM.show_shap_waterfall(model_index=4,
                         value_index=0)
# Out:
# SHAP values not calculated. Generating now
# Calculating shap_values for XGB depth:3 est:20

# %%
myEM.show_shap_summary(model_index=0)

# %% [markdown]
# # Persistence - Experiment Manager

# %%
filename_EM = f'{PROJECT_DIR}/testExperimentManager.pk.gz'
myEM.save(filename_EM)
# Out:
# Saving file as /home/magni/ML_Root/project_root/NLP-Pipeline/testExperimentManager

# %%
recoveredEM = ExperimentManager.load(filename_EM)

# %%
recoveredEM.display()
# Out:
# DataPackage summary
# Attributes:
# ---> uniqueColumn: uuid
# ---> dataColumn: review
# ---> targetColumn: sentiment
# Original Data:
# ---> original data shape: (50000, 3)
# Working Data:
# ---> working data shape: (50000, 102)
# Process:
# ---> isProcessed: True
# ---> isCleaned: True
# ---> isStopWorded: True
# ---> isBalanced: True
# ---> isEncoded: True
# ---> isTrainTestSplit: True
# Data:
# ---> isOrigDataLoaded: True
# ---> isTrainDataLoaded: True
# ---> isTestDataLoaded: True
#
# DataExperiment summary:
# ---> projectName: NLPipe
# ---> experimentName: XGB depth:10 est:100
# ---> isDataPackageLoaded: True
# ---> isProcessed: True
# ---> isModelLoaded: True
# ---> isModelPredicted: True
# ---> isModelLearningCurveCreated: False
# ---> isClassifierLoaded: True
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eval_metric='mlogloss', gamma=None,
#               gpu_id=0, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=10,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor='gpu_predictor', random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=None,
#               tree_method='gpu_hist', use_label_encoder=False,
#               validate_parameters=None, verbosity=None)
#
# DataExperiment summary:
# ---> projectName: NLPipe
# ---> experimentName: XGB depth:10 est:50
# ---> isDataPackageLoaded: True
# ---> isProcessed: True
# ---> isModelLoaded: True
# ---> isModelPredicted: True
# ---> isModelLearningCurveCreated: False
# ---> isClassifierLoaded: True
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eval_metric='mlogloss', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=10,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=None,
#               tree_method='gpu_hist', use_label_encoder=False,
#               validate_parameters=None, verbosity=None)
#
# DataExperiment summary:
# ---> projectName: NLPipe
# ---> experimentName: XGB depth:3 est:100
# ---> isDataPackageLoaded: True
# ---> isProcessed: True
# ---> isModelLoaded: True
# ---> isModelPredicted: True
# ---> isModelLearningCurveCreated: False
# ---> isClassifierLoaded: True
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eval_metric='mlogloss', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=3,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=None,
#               tree_method='gpu_hist', use_label_encoder=False,
#               validate_parameters=None, verbosity=None)
#
# DataExperiment summary:
# ---> projectName: NLPipe
# ---> experimentName: XGB depth:3 est:50
# ---> isDataPackageLoaded: True
# ---> isProcessed: True
# ---> isModelLoaded: True
# ---> isModelPredicted: True
# ---> isModelLearningCurveCreated: False
# ---> isClassifierLoaded: True
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eval_metric='mlogloss', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=3,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=None,
#               tree_method='gpu_hist', use_label_encoder=False,
#               validate_parameters=None, verbosity=None)
#
# DataExperiment summary:
# ---> projectName: NLPipe
# ---> experimentName: XGB depth:3 est:20
# ---> isDataPackageLoaded: True
# ---> isProcessed: True
# ---> isModelLoaded: True
# ---> isModelPredicted: True
# ---> isModelLearningCurveCreated: False
# ---> isClassifierLoaded: True
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eval_metric='mlogloss', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=3,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=20, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=None,
#               tree_method='gpu_hist', use_label_encoder=False,
#               validate_parameters=None, verbosity=None)
#
# [CV] END ..................., score=(train=0.999, test=0.708) total time=  39.5s
# [CV] END ..................., score=(train=0.956, test=0.724) total time=  36.1s
# [CV] END ..................., score=(train=0.765, test=0.730) total time=   3.9s
# [CV] END ..................., score=(train=0.828, test=0.703) total time=   1.8s
# [CV] END ..................., score=(train=0.771, test=0.707) total time=   0.7s
# [CV] END ..................., score=(train=0.997, test=0.710) total time=  53.8s
# [CV] END ..................., score=(train=0.957, test=0.725) total time=  36.2s
# [CV] END ..................., score=(train=0.822, test=0.718) total time=   3.5s
# [CV] END ..................., score=(train=0.745, test=0.731) total time=   1.9s
# [CV] END ..................., score=(train=0.724, test=0.717) total time=   0.9s
# [CV] END ..................., score=(train=1.000, test=0.707) total time=  30.7s
# [CV] END ..................., score=(train=0.990, test=0.710) total time=  31.6s
# [CV] END ..................., score=(train=0.955, test=0.714) total time=  35.5s
# [CV] END ..................., score=(train=0.783, test=0.726) total time=   3.7s
# [CV] END ..................., score=(train=0.795, test=0.717) total time=   1.7s
# [CV] END ..................., score=(train=0.729, test=0.716) total time=   1.0s
# [CV] END ..................., score=(train=1.000, test=0.708) total time=  22.1s
# [CV] END ..................., score=(train=1.000, test=0.685) total time=  25.7s
# [CV] END ..................., score=(train=1.000, test=0.703) total time=  17.7s
# [CV] END ..................., score=(train=0.998, test=0.685) total time=  14.6s
# [CV] END ..................., score=(train=0.834, test=0.730) total time=   3.3s
# [CV] END ..................., score=(train=0.836, test=0.713) total time=   0.6s
# [CV] END ..................., score=(train=0.800, test=0.709) total time=   1.7s
# [CV] END ..................., score=(train=0.775, test=0.702) total time=   0.8s
# [CV] END ..................., score=(train=0.999, test=0.702) total time=  38.5s
# [CV] END ..................., score=(train=0.996, test=0.707) total time=  22.4s
# [CV] END ..................., score=(train=0.892, test=0.713) total time=   0.5s
# [CV] END ..................., score=(train=0.891, test=0.695) total time=   3.3s
# [CV] END ..................., score=(train=0.757, test=0.726) total time=   2.1s
# [CV] END ..................., score=(train=0.749, test=0.709) total time=   0.8s
# [CV] END ..................., score=(train=0.997, test=0.707) total time=  53.0s
# [CV] END ..................., score=(train=0.995, test=0.708) total time=  23.0s
# [CV] END ..................., score=(train=0.779, test=0.731) total time=   2.9s
# [CV] END ..................., score=(train=0.787, test=0.721) total time=   1.2s
# [CV] END ..................., score=(train=0.788, test=0.715) total time=   1.8s
# [CV] END ..................., score=(train=0.735, test=0.714) total time=   0.8s
# [CV] END ..................., score=(train=0.990, test=0.727) total time=  59.9s
# [CV] END ..................., score=(train=0.955, test=0.716) total time=  35.8s
# [CV] END ..................., score=(train=0.880, test=0.702) total time=   3.9s
# [CV] END ..................., score=(train=0.759, test=0.720) total time=   1.9s
# [CV] END ..................., score=(train=0.723, test=0.714) total time=   1.0s
# [CV] END ..................., score=(train=0.991, test=0.723) total time=  59.8s
# [CV] END ..................., score=(train=0.982, test=0.702) total time=  32.5s
# [CV] END ..................., score=(train=0.886, test=0.705) total time=   3.4s
# [CV] END ..................., score=(train=0.794, test=0.725) total time=   1.3s
# [CV] END ..................., score=(train=0.761, test=0.719) total time=   1.1s
# [CV] END ..................., score=(train=0.772, test=0.699) total time=   0.8s
# [CV] END ..................., score=(train=1.000, test=0.706) total time=  39.0s
# [CV] END ..................., score=(train=0.982, test=0.715) total time=  32.2s
# [CV] END ..................., score=(train=0.883, test=0.714) total time=   3.7s
# [CV] END ..................., score=(train=0.754, test=0.729) total time=   0.5s
# [CV] END ..................., score=(train=0.843, test=0.696) total time=   1.6s
# [CV] END ..................., score=(train=0.745, test=0.704) total time=   0.9s
# [CV] END ..................., score=(train=1.000, test=0.701) total time=  37.9s
# [CV] END ..................., score=(train=1.000, test=0.703) total time=  18.2s
# [CV] END ..................., score=(train=0.981, test=0.703) total time=  18.9s
# [CV] END ..................., score=(train=0.786, test=0.723) total time=   3.6s
# [CV] END ..................., score=(train=0.830, test=0.706) total time=   1.5s
# [CV] END ..................., score=(train=0.750, test=0.718) total time=   0.6s
# [CV] END ..................., score=(train=0.724, test=0.710) total time=   1.0s
# [CV] END ..................., score=(train=0.999, test=0.693) total time=  30.1s
# [CV] END ..................., score=(train=0.997, test=0.700) total time=  31.4s
# [CV] END ..................., score=(train=0.980, test=0.704) total time=  32.3s
# [CV] END ..................., score=(train=0.762, test=0.739) total time=   3.7s
# [CV] END ..................., score=(train=0.795, test=0.722) total time=   1.7s
# [CV] END ..................., score=(train=0.749, test=0.714) total time=   0.4s
# [CV] END ..................., score=(train=0.756, test=0.702) total time=   0.8s
# [CV] END ..................., score=(train=0.991, test=0.711) total time= 1.0min
# [CV] END ..................., score=(train=0.998, test=0.691) total time=  17.9s
# [CV] END ..................., score=(train=0.996, test=0.693) total time=  16.8s
# [CV] END ..................., score=(train=0.835, test=0.716) total time=   3.8s
# [CV] END ..................., score=(train=0.762, test=0.729) total time=   1.5s
# [CV] END ..................., score=(train=0.772, test=0.708) total time=   0.5s
# [CV] END ..................., score=(train=0.733, test=0.713) total time=   0.8s
# [CV] END ..................., score=(train=0.990, test=0.714) total time= 1.0min
# [CV] END ..................., score=(train=0.995, test=0.702) total time=  22.6s
# [CV] END ..................., score=(train=0.837, test=0.722) total time=   1.8s
# [CV] END ..................., score=(train=0.839, test=0.710) total time=   2.3s
# [CV] END ..................., score=(train=0.747, test=0.724) total time=   2.2s
# [CV] END ..................., score=(train=0.725, test=0.709) total time=   1.2s
# [CV] END ..................., score=(train=1.000, test=0.690) total time=  29.1s
# [CV] END ..................., score=(train=1.000, test=0.692) total time=  27.8s
# [CV] END ..................., score=(train=0.996, test=0.701) total time=  23.6s
# [CV] END ..................., score=(train=0.762, test=0.735) total time=   3.8s
# [CV] END ..................., score=(train=0.831, test=0.717) total time=   2.2s
# [CV] END ..................., score=(train=0.730, test=0.707) total time=   0.6s
# [CV] END ..................., score=(train=0.724, test=0.705) total time=   0.8s
# [CV] END ..................., score=(train=0.998, test=0.711) total time=  54.0s
# [CV] END ..................., score=(train=0.999, test=0.689) total time=  18.2s
# [CV] END ..................., score=(train=0.953, test=0.707) total time=  19.2s
# [CV] END ..................., score=(train=0.768, test=0.722) total time=   3.3s
# [CV] END ..................., score=(train=0.746, test=0.730) total time=   2.0s
# [CV] END ..................., score=(train=0.748, test=0.714) total time=   0.5s
# [CV] END ..................., score=(train=0.784, test=0.695) total time=   1.0s
# [CV] END ..................., score=(train=0.998, test=0.713) total time=  53.4s
# [CV] END ..................., score=(train=0.981, test=0.711) total time=  32.5s
# [CV] END ..................., score=(train=0.780, test=0.731) total time=   3.0s
# [CV] END ..................., score=(train=0.766, test=0.723) total time=   1.2s
# [CV] END ..................., score=(train=0.751, test=0.719) total time=   2.1s
# [CV] END ..................., score=(train=0.730, test=0.704) total time=   1.2s

# %% [markdown]
# # Scratchpad
